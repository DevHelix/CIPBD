# %%
import pdfplumber
import csv
import re

# %%
pdf_path = rf"C:\Users\vince\Documents\GitHub\CIPBD\Long Beach\Test\2025-page49.pdf"
records  = []
with pdfplumber.open(pdf_path) as pdf:
    for pg in pdf.pages:
        txt = pg.extract_text() or ''
        print(txt)
# Out:
# Mobility and Safety
# ADA RAPID RESPONSE 3003010000
# Project Description Construct access ramps and sidewalks on public right-of-
# way based on verified request.
# Estimated Operating Repair and maintenance to prolong the life of residential sidewalks and reduce future infrastructure
# and Maintenance expenses related to normal erosion, root damage and heavy pedestrian usage in compliance with ADA
# specifications.
# Project Timeline Design and construction on a continuous basis.
# Department Contact Public Works - Engineering - Keith Hoey - (562) 570-5786
# Funding Sources
# Funding Source Beginning Balance FY 26 FY 27 FY 28 3 Year Total
# CAPITAL PROJECTS $43,166 $0 $0 $0 $43,166
# GAS TAX STREET IMPROVEMENTS $145,011 $800,000 $800,000 $800,000 $2,545,011
# TIDELANDS CAPITAL PROJECTS $150,000 $0 $0 $0 $150,000
# Total $338,178 $800,000 $800,000 $800,000 $2,738,178
# FY 26 Adopted CIP 46 City of Long Beach - Mobility and Safety
